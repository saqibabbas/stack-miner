# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns;
import matplotlib.pyplot as plt

import numpy as np ;

# %%
questions=pd.read_csv('aQuestions.csv')
users=pd.read_csv('aUsers.csv')
answers=pd.read_csv('aAnswers.csv')

# %%
questions.head()
# Out:
#          id                                              title  \
# 0  57599848  Android SEND action intent filter for a partic...
# 1  57496869                    Htacces redirect specific slugs
# 2  57543112    ServiceStack.Aws.DynamoDb: Is there async APIs?
# 3  57687711   Integrating Firebase Crashlytics with Prometheus
# 4  57571133  How to change tibble's cells by quasiquotation...
#
#    accepted_answer_id  answer_count  comment_count community_owned_date  \
# 0            57599983             1              0                  NaN
# 1            57497234             1              0                  NaN
# 2            57545425             1              0                  NaN
# 3            57717188             1              0                  NaN
# 4            57571186             2              0                  NaN
#
#                  creation_date           last_activity_date last_edit_date  \
# ...

# %%
df1=questions[['id','accepted_answer_id','creation_date']]
answers.head()
# Out:
#          id                creation_date owner_display_name  owner_user_id  \
# 0    579836  2009-02-23 23:21:55.293 UTC    Adam Rosenfield           9530
# 1     96731  2008-09-18 20:42:58.847 UTC       Michael Stum             91
# 2     96722   2008-09-18 20:41:47.93 UTC             mmyers          13531
# 3    102455   2008-09-19 14:50:10.22 UTC      Ben Hoffstein           4482
# 4  54234947  2019-01-17 11:28:14.697 UTC                NaN        8938829
#
#    parent_id  post_type_id  score                          location
# 0   12887700             2     36                     United States
# 1    7101992             2      7        Raleigh, NC, United States
# 2    7101992             2     81                     United States
# 3    4659220             2      0  New York, New York United States
# 4   54231976             2      0          Jaipur, Rajasthan, India

# %%
df2=answers[['id','creation_date']]

# %%
df1['answerid']=df1['accepted_answer_id']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
  df2
# Out:
#               id                creation_date  answerid
# 0         579836  2009-02-23 23:21:55.293 UTC    579836
# 1          96731  2008-09-18 20:42:58.847 UTC     96731
# 2          96722   2008-09-18 20:41:47.93 UTC     96722
# 3         102455   2008-09-19 14:50:10.22 UTC    102455
# 4       54234947  2019-01-17 11:28:14.697 UTC  54234947
# ...          ...                          ...       ...
# 907760  52075578   2018-08-29 10:47:36.75 UTC  52075578
# 907761  51997518  2018-08-24 04:32:26.883 UTC  51997518
# 907762  51987693   2018-08-23 14:02:41.77 UTC  51987693
# 907763  52051129   2018-08-28 06:06:12.15 UTC  52051129
# 907764  52434756  2018-09-20 23:49:26.733 UTC  52434756
#
# [907765 rows x 3 columns]

# %%
final=pd.merge(df1,df2,on='answerid')
final
# Out:
#             id_x  accepted_answer_id              creation_date_x  answerid  \
# 0       57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1       57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2       57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3       57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4       57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
# ...          ...                 ...                          ...       ...
# 493569   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493570   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493571   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493572   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493573   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
#
#             id_y              creation_date_y
# ...

# %%
(pd.to_datetime(final['creation_date_y'])-pd.to_datetime(final['creation_date_x'])).dt.days
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 493569    0
# 493570    0
# 493571    0
# 493572    0
# 493573    0
# Length: 493574, dtype: int64

# %%
(pd.to_datetime(final['creation_date_y'])-pd.to_datetime(final['creation_date_x'])).days
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-8065b4baeab0> in <module>
# ----> 1 (pd.to_datetime(final['creation_date_y'])-pd.to_datetime(final['creation_date_x'])).days
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'days'

# %%
final['timeDiff']=pd.to_datetime(final['creation_date_y'])-pd.to_datetime(final['creation_date_x'])
final['DayDiff']=(pd.to_datetime(final['creation_date_y'])-pd.to_datetime(final['creation_date_x'])).dt.days

# %%
final
# Out:
#             id_x  accepted_answer_id              creation_date_x  answerid  \
# 0       57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1       57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2       57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3       57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4       57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
# ...          ...                 ...                          ...       ...
# 493569   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493570   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493571   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493572   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493573   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
#
# ...

# %%
final
# Out:
# 0        0 days 00:15:58.230000
# 1        0 days 00:20:13.870000
# 2        0 days 05:16:22.390000
# 3        1 days 12:05:48.800000
# 4        0 days 00:03:23.900000
#                   ...
# 493569   0 days 00:06:32.446000
# 493570   0 days 00:06:32.446000
# 493571   0 days 00:06:32.446000
# 493572   0 days 00:06:32.446000
# 493573   0 days 00:06:32.446000
# Name: timeDiff, Length: 493574, dtype: timedelta64[ns]

# %%
print(final['timeDiff'][5])
print(final['timeDiff'][6])
print(final['timeDiff'][7])
print(final['timeDiff'][80])
print(final['timeDiff'][90])
print(final['timeDiff'][120])
print(final['timeDiff'][110])
print(final['timeDiff'][100])
print(final['timeDiff'][111])
print(final['timeDiff'][115])
print(final['timeDiff'][44
])
print(final['timeDiff'][15])
# Out:
# 0 days 00:07:46.590000
# 0 days 00:12:10.640000
# 0 days 00:03:50.133000
# 0 days 00:05:30.340000
# 0 days 00:17:32.456000
# 0 days 08:39:59.883000
# 0 days 00:20:21.127000
# 0 days 00:20:59.293000
# 0 days 00:36:35.110000
# 0 days 00:04:35.987000
# 0 days 00:07:11.897000
# 0 days 00:45:47.400000

# %%
x,y,z= (final['timeDiff'].astype(str).str.split('s ')[1])[1].split(':')
print(x)
print(y)
print(z)
# Out:
# 00
# 20
# 13.870000000

# %%
final.head()
# Out:
#        id_x  accepted_answer_id              creation_date_x  answerid  \
# 0  57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1  57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2  57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3  57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4  57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
#
#        id_y              creation_date_y               timeDiff  DayDiff
# 0  57599983   2019-08-21 22:37:56.08 UTC 0 days 00:15:58.230000        0
# 1  57497234  2019-08-14 14:57:10.517 UTC 0 days 00:20:13.870000        0
# 2  57545425  2019-08-18 14:20:16.717 UTC 0 days 05:16:22.390000        0
# 3  57717188  2019-08-29 20:13:28.687 UTC 1 days 12:05:48.800000        1
# 4  57571186   2019-08-20 10:02:03.64 UTC 0 days 00:03:23.900000        0

# %%
(final['timeDiff'].astype(str).str.split('s ')[1])
# Out:
# ['0 day', '00:20:13.870000000']

# %%
final
# Out:
#             id_x  accepted_answer_id              creation_date_x  answerid  \
# 0       57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1       57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2       57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3       57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4       57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
# ...          ...                 ...                          ...       ...
# 493569   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493570   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493571   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493572   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493573   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
#
# ...

# %%
(final['creation_date_y'][0].split(' UTC')[0]).astype(date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-371935242187> in <module>
# ----> 1 (final['creation_date_y'][0].split(' UTC')[0]).astype(date)
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
final['diffMinutes']=(pd.to_datetime(final.creation_date_y.str.split(' UTC')[0])-pd.to_datetime(final.creation_date_x.str.split(' UTC')[0])).seconds/60.00
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-b7926fb0366f> in <module>
# ----> 1 final['diffMinutes']=(pd.to_datetime(final.creation_date_y.str.split(' UTC')[0])-pd.to_datetime(final.creation_date_x.str.split(' UTC')[0])).seconds/60.00
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# ...

# %%
time
# Out:
# Timedelta('0 days 00:15:58.230000')

# %%
time.seconds
# Out:
# 958

# %%
final
# Out:
#             id_x  accepted_answer_id              creation_date_x  answerid  \
# 0       57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1       57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2       57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3       57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4       57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
# ...          ...                 ...                          ...       ...
# 493569   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493570   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493571   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493572   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
# 493573   5767325             5767357  2011-04-23 22:17:18.487 UTC   5767357
#
# ...

# %%
final['Minutes']=final['timeDiff'].astype('timedelta64[m]')

# %%
final.head()
# Out:
#        id_x  accepted_answer_id              creation_date_x  answerid  \
# 0  57599848            57599983   2019-08-21 22:21:57.85 UTC  57599983
# 1  57496869            57497234  2019-08-14 14:36:56.647 UTC  57497234
# 2  57543112            57545425  2019-08-18 09:03:54.327 UTC  57545425
# 3  57687711            57717188  2019-08-28 08:07:39.887 UTC  57717188
# 4  57571133            57571186   2019-08-20 09:58:39.74 UTC  57571186
#
#        id_y              creation_date_y               timeDiff  DayDiff  \
# 0  57599983   2019-08-21 22:37:56.08 UTC 0 days 00:15:58.230000        0
# 1  57497234  2019-08-14 14:57:10.517 UTC 0 days 00:20:13.870000        0
# 2  57545425  2019-08-18 14:20:16.717 UTC 0 days 05:16:22.390000        0
# 3  57717188  2019-08-29 20:13:28.687 UTC 1 days 12:05:48.800000        1
# 4  57571186   2019-08-20 10:02:03.64 UTC 0 days 00:03:23.900000        0
#
#    Minutes
# 0     15.0
# 1     20.0
# 2    316.0
# 3   2165.0
# 4      3.0

# %%
from sklearn import linear_model,metrics
from sklearn.model_selection import train_test_split
X=final.drop(['creation_date_x','creation_date_y','timeDiff','DayDiff'],axis='columns')
Y=final['Minutes']

# %%
X
# Out:
#             id_x  accepted_answer_id  answerid      id_y  Minutes
# 0       57599848            57599983  57599983  57599983     15.0
# 1       57496869            57497234  57497234  57497234     20.0
# 2       57543112            57545425  57545425  57545425    316.0
# 3       57687711            57717188  57717188  57717188   2165.0
# 4       57571133            57571186  57571186  57571186      3.0
# ...          ...                 ...       ...       ...      ...
# 493569   5767325             5767357   5767357   5767357      6.0
# 493570   5767325             5767357   5767357   5767357      6.0
# 493571   5767325             5767357   5767357   5767357      6.0
# 493572   5767325             5767357   5767357   5767357      6.0
# 493573   5767325             5767357   5767357   5767357      6.0
#
# [493574 rows x 5 columns]

# %%
y
# Out:
# '20'

# %%
Y
# Out:
# 0           15.0
# 1           20.0
# 2          316.0
# 3         2165.0
# 4            3.0
#            ...
# 493569       6.0
# 493570       6.0
# 493571       6.0
# 493572       6.0
# 493573       6.0
# Name: Minutes, Length: 493574, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#             id_x  accepted_answer_id  answerid      id_y   Minutes
# 134108  35370296            35370329  35370329  35370329       2.0
# 141673  23930575            23930609  23930609  23930609       1.0
# 69187   33363373            33376251  33376251  33376251     604.0
# 394760  12232095            12232367  12232367  12232367      60.0
# 354094  13857589            13857724  13857724  13857724       7.0
# ...          ...                 ...       ...       ...       ...
# 491263   5748638             5748772   5748772   5748772      11.0
# 267336  16387984            16388086  16388086  16388086      10.0
# 470924  21324828            32764250  32764250  32764250  876100.0
# 491755   6155188             6155246   6155246   6155246       5.0
# 128037   6406482             6437995   6437995   6437995    3286.0
#
# [394859 rows x 5 columns]

# %%
Y_train
# Out:
# 134108         2.0
# 141673         1.0
# 69187        604.0
# 394760        60.0
# 354094         7.0
#             ...
# 491263        11.0
# 267336        10.0
# 470924    876100.0
# 491755         5.0
# 128037      3286.0
# Name: Minutes, Length: 394859, dtype: float64

# %%
X_test
# Out:
#             id_x  accepted_answer_id  answerid      id_y  Minutes
# 416335  39653508            39655606  39655606  39655606    122.0
# 355766  14175029            14175058  14175058  14175058      3.0
# 31211   36637211            36637788  36637788  36637788     71.0
# 155417  20181219            20181492  20181492  20181492     25.0
# 93995   46201109            46289470  46289470  46289470   7683.0
# ...          ...                 ...       ...       ...      ...
# 111820  17581477            17581627  17581627  17581627      8.0
# 262010  13698236            13800249  13800249  13800249   8873.0
# 161937  36294085            36298875  36298875  36298875    419.0
# 317416  25815377            25815414  25815414  25815414      2.0
# 2636    36035675            36036434  36036434  36036434     32.0
#
# [98715 rows x 5 columns]

# %%
len(X_train)
# Out:
# 394859

# %%
len(X_test)
# Out:
# 98715

# %%
linearRegression=linear_model.LinearRegression()

# %%
linearRegression.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Coeffcients',linearRegression.coef_)
print('variance {}'.format(linearRegression.score(X_test,Y_test)))
# Out:
# Coeffcients [-9.48113927e-15  1.39736393e-15  3.99571082e-15  4.03092029e-15
#   1.00000000e+00]
# variance 1.0

# %%
predictedValue=linearRegression.predict(X_test)

# %%
len(predictedValue)
# Out:
# 98715

# %%
OneHour=predictedValue[predictedValue<=60]
MoreThanOneHour=predictedValue[(predictedValue>60) & (predictedValue <120)]
MoreThanTwoHour=predictedValue[predictedValue>=120]

# %%
print(OneHour)
print(MoreThanOneHour)
print(MoreThanTwoHour)
# Out:
# [ 3. 25. 10. ...  8.  2. 32.]
# [71. 62. 80. ... 68. 63. 99.]
# [ 122. 7683.  252. ...  317. 8873.  419.]

# %%
len(OneHour)
# Out:
# 60135

# %%
import seaborn as sns

# %%
sns.boxplot(predictedValue)

# %%
np.array([OneHour],[MoreThanOneHour],[MoreThanTwoHour])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-c94a4528700f> in <module>
# ----> 1 np.array([OneHour],[MoreThanOneHour],[MoreThanTwoHour])
#
# ValueError: only 2 non-keyword arguments accepted

# %%
pred=pd.DataFrame({'OneHour':OneHour,'MoreThanOneHour':MoreThanOneHour,'MoreThanTwoHour':MoreThanTwoHour})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-9cccc4258c32> in <module>
# ----> 1 pred=pd.DataFrame({'OneHour':OneHour,'MoreThanOneHour':MoreThanOneHour,'MoreThanTwoHour':MoreThanTwoHour})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# ...

# %%
pred
# Out:
#                                              OneHour  \
# 0  [2.9999999981643297, 24.99999999782332, 9.9999...
#
#                                      MoreThanOneHour  \
# 0  [70.99999999688563, 61.999999997847766, 79.999...
#
#                                      MoreThanTwoHour
# 0  [121.9999999967274, 7682.999999997135, 251.999...

# %%
list1=pd.DataFrame({'OneHour':[OneHour]})
list2=pd.DataFrame({'MoreThanOneHour':[MoreThanOneHour]})
list3=pd.DataFrame({'MoreThanTwoHour':[MoreThanTwoHour]})

# %%
list4=pd.merge(list1,list2,list3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-192-def9f1a6372f> in <module>
# ----> 1 list4=pd.merge(list1,list2,list3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ...

# %%
Hour1=(len(OneHour)/len(predictedValue))*100
HourMoreThan1=(len(MoreThanOneHour)/len(predictedValue))*100
HourMoreThan2=(len(MoreThanTwoHour)/len(predictedValue))*100

# %%
df=pd.DataFrame({'Time': ['<=1 Hour','1-2 Hour','>2 Hour'], 'Percentage': [Hour1,HourMoreThan1,HourMoreThan2]})

# %%
ax = sns.barplot(x="Time", y="Percentage", data=df)
